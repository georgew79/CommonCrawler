# %%
from Lib.net_utils import download_wet_file
from Lib.text_utils import process_wet, default_filter

# %%
sample_url = 'https://data.commoncrawl.org/crawl-data/CC-MAIN-2022-05/segments/1642320299852.23/wet/CC-MAIN-20220116093137-20220116123137-00000.warc.wet.gz'
sample_file_directory = 'UNZIPPED.warc'

# %% [markdown]
# (NOTE keyboard interrupts used below, but captured)

# %% [markdown]
# # Download and Process Text

# %%
# NOTE: This was interrupted on purpose
text = download_wet_file(sample_url, should_capture=True, should_split=True)
# Out:
# 134MiB [00:02, 63.2MiB/s]
# 4309it [00:04, 528.55it/s]
# Processed 4326 blocks

# %% [markdown]
# # Process Text Directly

# %%
text = process_wet(sample_file_directory, should_capture=True, should_split=True, b_remove_html=False, filter_func=default_filter)
# Out:
# 3597it [00:03, 551.47it/s]
# Processed 3604 blocks

# %%
print(len(text))
# Out:
# 344625

# %%
text[:500]
# Out:
# ['SoftwareInfo iawebcommonsSNAPSHOT',
#  'ExtractedDate Sat  Jan   GMT',
#  'robots checked via crawlercommons SNAPSHOT httpsgithubcomcrawlercommonscrawlercommons',
#  'isPartOf CCMAIN',
#  'operator Common Crawl Admin infocommoncrawlorg',
#  'description Wide crawl of the web for January ',
#  'publisher Common Crawl',
#  ' O O O O O O O',
#  ' O O O O O O',
#  'TOD',
#  'O',
#  'TOD',
#  'O',
#  'O',
#  'O',
#  'ICP  B',
#  ' shtmlvideoappendTodocumentbodyvar videoObject    container videoContainerIDclass  variable playernew chplayer  looptrue   videohttpimgksbbscomassetMoncacbefdemp  flashplayerfalseflashplayertrue    var playernew ckplayervideoObject',
#  ' O O O O O O O',
#  ' O O O O O O',
#  ' O O O O O O',
#  ' O O O O O O O',
#  'OOOO',
#  'O',
#  'OOO',
#  'O',
#  'OO',
#  'O',
#  'Z',
#  'B',
#  'O',
#  'O',
#  'O',
#  'O',
#  'ICP  B',
#  'wwwboschsiemensodua',
#  '  bosch  siemens          bosch ',
#  '  bosch  siemens          bosch ',
#  '  httpodua  ',
#  'phraseitemsCount ',
#  ' lat PCK',
#  'Strona gwna',
#  'O nas',
#  ' rocznica',
#  'Kalendarium',
#  'Fakty',
#  'Kontakt',
#  'Strona gwna',
#  'Strona gwna PCK',
#  'PCK na Facebooku',
#  'Pawe Sapieha',
#  'Fot Pawe Sapieha',
#  'Pawe Jan Sapieha zosta pierwszym prezesem Komitetu Gwnego Polskiego Towarzystwa Czerwonego Krzya    By liderem nowo powstaego stowarzyszenia po odzyskaniu przez Polsk niepodlegoci Ju od  r Sapieha dziaa na rzecz spoeczestwa pocztkowo jako prezes Krajowego Stowarzyszenia Czerwonego Krzya Mczyzn i Dam w Galicji z siedzib we Lwowie W zwizku z wybuchem I Wojny wiatowej priorytetowym zadaniem stowarzyszenia Sapiehy byo przygotowanie i urzdzenie licznych szpitali i punktw opatrunkowych Czerwonego Krzya',
#  'Wraz z przesuwajcym si frontem nazewnictwo organizacji czerwonokrzyskich w Maopolsce ulegao zmianom i jego nazwy brzmiay kolejno Galicyjskie Towarzystwo Czerwonego Krzya we Lwowie Krajowego Stowarzyszenie Czerwonego Krzya dla Galicji z siedzib we Lwowie Prezesem tych organizacji w rnym okresie ich trwania by cay czas ksi Sapieha Jednym z pierwszych rozkazw Naczelnego Dowdcy Wojsk Polskich w Galicji Wschodniej byo powoanie w dniu  listopada  r Krajowego Stowarzyszenia Czerwonego Krzya dla Galicji Podczas walk toczcych si w tym okresie we Lwowie Towarzystwo przystpio natychmiast do organizacji szpitali oraz stacji ratunkowych Po ogoszeniu niepodlegoci Polski i jej uznania przez mocarstwa zachodnie powstaa konieczno zjednoczenia organizacji z trzech zaborw w jedn organizacj czerwonokrzysk  Polskiego Towarzystwa Czerwonego Krzya na czele ktrego pocztkowo rwnie stan Sapieha',
#  'Polskie Towarzystwo Czerwonego Krzya  Fakty Cytat Marszaka Pisudskiego o Czerwonym Krzyu',
#  'Honorowy patronat Maonki Prezydenta RP Agaty KornhauserDudy',
#  'Copyright   PCK Created by KDK',
#  'NILAI IKM DAN IPK PENGADILAN AGAMA MUARA TEBO',
#  'NILAI IKM DAN IPK PENGADILAN AGAMA MUARA TEBO',
#  'NILAI IKM',
#  'NILAI IPK',
#  'hasil survei berdasarkan survei online dari Aplikasi SIPAMTO',
#  'Google    Wear  OS        ',
#  ' IT',
#  'Google    Wear  OS     ',
#  '   AdminGWP',
#  'eo a o o Apple Watch oa  eeox oeax oo oax x ao a         Wear    OS',
#  ' Google                 Android     Apple Watch            ',
#  '                    Qualcomm            Wear  OS          Apple Watch',
#  '   Google         Google User Experience       Wear OS                     ',
#  '     Google                                               Wear OS   ',
#  '           Qualcomm        ',
#  '  Samsung Display      AMOLED  ',
#  '  Android     InnoGames ',
#  ' IT',
#  'Evergrande       ',
#  'Xiaomi Note           OmniVision OVBB',
#  '  Thermaltake Toughpower PF       ',
#  ' Forbidden',
#  ' Forbidden',
#  'nginx',
#  ' Forbidden',
#  ' Forbidden',
#  'nginx',
#  'TOP ',
#  'TOP  kpccombarmclothhtml     TOP            kpccombarmclothhtml    ',
#  'mm',
#  '  mm    inch',
#  'mminch',
#  ' x ',
#  'x',
#  'xX  X',
#  'x',
#  'x',
#  'x',
#  'x',
#  'x',
#  'x',
#  'x',
#  'x',
#  '       g',
#  'WIKI',
#  'WIKIWIKI',
#  'WIKI',
#  'WIKI',
#  'LCD',
#  'WIKI',
#  'LEDCM V C        X  caihv AWG     AWG AWG RCAWG    AWG X  V Specification      aWGAWG brother  TZe mm  Size       Brown      Color  C    Brown             Key         Key            H HILABEE xDSGHPC DSGH PC Guide EKEF  EKEF FKFF  BKBF DL mm Color  BKBF BKBF RM Length  BKBF mm YYYYyan   Sfu SFU inner mm  SFU     SFU MONOKING          SUP   Na                         Na          Na          PEG        mmmmmm                    USJ     L        PVC                                              X          AT     Tamaliving          Color   pc   g      g  LEDXL    RC XL  lifier lifier XL lifier  tee   Colore  pcs          cm          g             g    in x                g     g      g   ',
#  'WIKI',
#  'WIKI',
#  'WIKI',
#  'WIKIWIKI',
#  'WIKIWIKI',
#  'WIKI ',
#  'HOTWIKI',
#  'Kinmy U',
#  ' Wiki',
#  ' Wiki',
#  '  Lchic ',
#  '   Wiki',
#  '    Wiki',
#  ' Wiki',
#  'Grim Dawn wiki Wiki',
#  '   g',
#  'Wiki',
#  'WIKI',
#  'LostWord Wiki',
#  'Grim Dawn wiki Wiki',
#  ' Wiki',
#  'J Wiki',
#  ' Wiki',
#  'factoriojp Wiki',
#  'Among Us  MOD  Wiki',
#  'VIP Wiki',
#  ' Wiki',
#  'Wiki',
#  ' Days to Die Japan Wiki',
#  ' Wiki',
#  ' Wiki',
#  'SideM GROWING STARS Wiki',
#  ' ggg',
#  ' SPECIAL  Wiki',
#  'Escape from Tarkov Wiki',
#  ' Wiki',
#  ' Wiki',
#  'Muse Dash Wiki',
#  ' Wiki',
#  ' Wiki',
#  '   Wiki',
#  'Women Headband Boho Floal Elastic Cotton Turban Head Wrap Twist Knot Hair Band  Pack pattern   ',
#  'VIP Wiki',
#  'inc  Wiki',
#  'Call of War Wiki',
#  ' Wiki',
#  ' Wiki',
#  ' Wiki',
#  'SnowRunner Wiki',
#  ' Wiki',
#  ' Wiki',
#  ' Wiki',
#  'Satisfactory Wiki',
#  ' Wiki',
#  ' Wiki',
#  '    Wiki',
#  ' Wiki',
#  'VS Wiki',
#  'HBIN  Size  xxcm',
#  'world of warships blitz Wiki',
#  ' Wiki',
#  'AngelLoveOnline Wiki',
#  'BLCD Wiki',
#  ' Wiki',
#  '   Wiki',
#  ' Wiki',
#  'Splatoon    Wiki',
#  'HJFC Wiki',
#  'Arcaea Wiki',
#  ' Crossout Wiki',
#  'Mabinogi Wiki',
#  ' Wiki',
#  ' Wiki',
#  ' Wiki',
#  'ARKSurvivalEvolved Wiki',
#  ' Wiki',
#  ' Wiki',
#  'Wiki Wiki',
#  ' Wiki',
#  'MHzdBRFVHF UHFRF',
#  '  Wiki',
#  'Extra Wiki',
#  'World of Tanks PS Wiki',
#  'aleppo Wiki',
#  '  Wiki',
#  'wiki Wiki',
#  ' Wiki',
#  ' API  Wiki',
#  'Deep Rock Galactic Wiki',
#  '  Wiki',
#  ' Wiki',
#  'StellarisJP Wiki',
#  ' Wiki',
#  ' Wiki',
#  ' Wiki',
#  ' Wiki',
#  'Railway Empire  Wiki',
#  'VIPGT Wiki',
#  'KINGDOM HEARTS Wiki',
#  'WonderlandONLINEM Wiki',
#  'J Wiki',
#  ' Wiki',
#  ' Wiki',
#  'Phigros Wiki',
#  'Microsoft Flight Simulator  Wiki',
#  '                              L',
#  'War Thunder Wiki',
#  ' Wiki',
#  ' Wiki',
#  'ONLINE Wiki',
#  'World of Warships Legends Wiki',
#  'Slay the Spire Wiki',
#  'J Wiki',
#  'DQ Wiki',
#  'sideM Wiki',
#  'WIKIWIKITwitter',
#  'Tweets by WIKIWIKIJapan',
#  'WIKIWIKI',
#  'WIKI',
#  'WIKI',
#  'zawazawa',
#  'WIKIWIKI',
#  '  M      ',
#  'CopyrightC Since  WIKIWIKI All Rights Reserved',
#  'bbs',
#  '  DIY',
#  'Home',
#  'Realestate',
#  'Rent',
#  'Share',
#  'Business',
#  'Commercial',
#  'Sold',
#  'Forum',
#  'Services',
#  'Forex',
#  'Community',
#  'BBSPerthbbscom   ',
#  'Brisbane',
#  'Goldcoast',
#  ' Brisbane    ',
#  ' HomeLoanExpert   HomeLoanExpert    ',
#  ' Brisbane  HOME LOAN SPECIALIST   ',
#  ' SPmortgage   SPmortgage    ',
#  'Brisbane o',
#  'Brisbane  Warwick ',
#  ' jschloechloe   jschloechloe    ',
#  'Brisbane  Chole  Tao home',
#  'Brisbane ',
#  ' GWCP   GWCP    ',
#  'Brisbane   ',
#  ' GWCP   GWCP    ',
#  'Brisbane   ',
#  ' GWCP   GWCP    ',
#  'Brisbane ',
#  ' GWCP   GWCP    ',
#  'Brisbane   ',
#  ' GWCP   GWCP    ',
#  'Brisbane ',
#  ' GWCP   GWCP    ',
#  'Brisbane GWCP',
#  ' GWCP   GWCP    ',
#  'Brisbane  vs  ',
#  ' GWCP   GWCP    ',
#  'Brisbane ',
#  ' GWCP   GWCP    ',
#  'Brisbane   ',
#  'Brisbane ',
#  'Brisbane ',
#  'Brisbane ',
#  'Brisbane ',
#  'Brisbane  Rowville ',
#  'Brisbane ',
#  'Brisbane   Collins St',
#  'Brisbane ',
#  'Brisbane ',
#  'Brisbane  Reservoir ',
#  'Brisbane  Vanguard',
#  'Goldcoast CBDCoburg  BLVD Gardens ',
#  'Brisbane BoxHillFortune ',
#  'Brisbane Bond Quarter',
#  'Brisbane apartment',
#  'Brisbane   ',
#  ' HomeLoanExpert   HomeLoanExpert    ',
#  'Brisbane HOME LOAN SPEICIALIST    ',
#  ' SPmortgage   SPmortgage    ',
#  'Brisbane ',
#  ' ElvinGAO   ElvinGAO    ',
#  'Brisbane  ',
#  ' LucasL   LucasL    ',
#  'Goldcoast Box HillArnold',
#  'Brisbane ',
#  'Brisbane Box HillArnold',
#  'Brisbane stlucia',
#  ' syd   syd    ',
#  'Brisbane ',
#  ' aliendu   husco    ',
#  'Brisbane ',
#  ' duduhan   smsm    ',
#  'Brisbane Building and Pest',
#  ' abc   abc    ',
#  'Brisbane ',
#  ' aliendu   aliendu    ',
#  'Brisbane  ',
#  'Brisbane ',
#  ' nikii   nikii    ',
#  'Goldcoast Griffith',
#  'Brisbane  Town house ',
#  ' daveminton   Aman    ',
#  'Brisbane house',
#  ' Hamilton   daveminton    ',
#  'Goldcoast Griffith Library',
#  'Brisbane RPDATA',
#  ' luckymoth   luckymoth    ',
#  'Brisbane Brisbane state high ',
#  ' dlthomas   dlthomas    ',
#  'Brisbane Goldcoast',
#  'B Color Image Link Quote Code Smilies',
#  'PTE',
#  'IELTS ',
#  'BNE',
#  'UI Global PY NA',
#  'HT  ',
#  'Benchmark',
#  'LITTLES LAWYERS',
#  'Aston Lawyers',
#  'SP MORTGAGE ',
#  'Kevin Kevin',
#  'EzylifeBOND',
#  'QLDAnyphoto Studio',
#  'Copyright   OZYOYOcom All rights reserved',
#  'brewery',
#  'brewery',
#  'Belgian style witbier',
#  'Paleale',
#  'Redale',
#  'Hazelnut stout',
#  'ml',
#  ' brewery  ',
#  'BlogThisTwitter Facebook Pinterest ',
#  'Wheat land',
#  'Red ale',
#  'Hazy IPA Type',
#  ' g or ml',
#  'ml',
#  'JR',
#  'references',
#  'references',
#  ' Belgian style witbier',
#  '  gaffera  Powered by Blogger',
#  ' sunbet',
#  'sunbet',
#  'QQ',
#  'RCEP',
#  'WTO',
#  'sunbet',
#  'httpshonlybokeenet',
#  'AMBA',
#  'UCID',
#  'shonly    ',
#  'wwwicom',
#  'Power by DedeCms',
#  'No LV   No LV  ',
#  'No LV   No LV   No LV   No LV  ',
#  'No LV   No LV   No LV   No LV  ',
#  'Jinx    ',
#  '  cm',
#  '  kg',
#  ' LV       ',
#  ' LV        ',
#  ' LV  DDChein     ',
#  ' LV       ',
#  ' LV  next     ',
#  ' LV  XianX     ',
#  ' LV       ',
#  ' LV       ',
#  ' LV  ATM     ',
#  ' LV          ',
#  ' LV  Q     ',
#  'Copyright   By  All Rights Reserved',
#  '  TICRF ',
#  ' ATMWebATM    ',
#  'A',
#  'B',
#  'C',
#  'D',
#  'E',
#  'G',
#  'A',
#  'B',
#  'C',
#  'Hi',
#  'Email',
#  ' EMail EMail ',
#  'Copyright   By  All Rights Reserved',
#  '           Chateau Du HautKoenigsbourg           ',
#  '       Reims                                            XI                                                ',
#  '   Metz                                                        ',
#  '    Strasbourg                                                       ',
#  '   hteau du HautKoenigsbourg                                     ',
#  '                    Riquewihr  ',
#  '   Colmar                 ',
#  ' Dijon           VI                       XII          Salle des gardes                                      XI ',
#  '     Beaune                                     Hospices de Beaune                   ',
#  '     EUR              EUR        EUR          ',
#  'YouTRAVELlife',
#  'YouTRAVELlife',
#  'YouTRAVELlife',
#  'YouTRAVELlife',
#  'Previous Next',
#  '  YouTRAVELlife',
#  'httpswwwfacebookcomYouTRAVELlife',
#  'bookingyoutravellife',
#  'httpsyoutravellife',
#  ' Telegram  Viber',
#  'what is economies of scale',
#  'what is economies of scale',
#  'HOME',
#  'PORTFOLIO',
#  'CONTACTS',
#  'This is because fixed costs such as administration rent and the like are distributed across a higher number of production units The advantage comes from the inverse relationship quantity of units produced and fixed cost per unitIt often acts as a key source of competitive advantage for largescale organizations over small ones Economies of scope are different to economies of scale  though there is the same principle of larger firms benefiting from lower average costs Economies of scale provide larger companies with a competitive advantage over smaller ones because the larger the business the lower its perunit costs The principal difference between economies of scale and economies of scope is the former represents the benefits received by increasing the scale of production while the latter refers to the benefits obtained due to producing multiple products using the same operations efficiently Economies of Scale in the case of Alexs company helped his company become profitable once it achieved a certain production figure This is the idea that as a business grows and expands it can split its marketing costs over more units of production and it can do things like purchase advertising space in magazines on TV channels in larger quantities In other words the cost of production per unit decreases as a company produces more units Here are some examples Industry growth may allow you access to specialist or lowercost suppliers It means the economies benefit the firm when it grows in size This is the advantage that many large companies enjoy with their suppliers Most of the above economies of scale are internal For instance the cost of producing two hundred exercise books can be ten dollars but the cost of producing four hundred exercise books is twelve dollars Internal economies of scale It is important not to confuse total cost with average cost Economies of scope focus on the average total cost of production of a variety of goods This reduction is known as economy of scale Marketing Economies of Scale Studies in economies of scale A common example of economies of scale in action is seen when looking  Economies of scale means large organisations can often produce items at a lower unit cost than their smaller rivals  a source of competitive advantage Although overall costs may be increasing perunit costs decrease which leaves more room for profit and the success of the company Economies of scale are achieved when increasing the scale of production decreases longterm average costs Economies of scope Economies of scale refers to the economic advantage for an organization owing to its increased level of output Example of economies of scale Economies of scale are the elements that contribute to the fall of the average production cost as the quantity produced increases In contrast economies of scale focus on the cost advantage that  Increased labour As a firm grows in size its total costs rise because it is necessary to use more resources External Economies of Scale External economies of scale occur where a company gains advantages as a result of events and developments in the industry as a whole and in the external environment Economies of scope occur when a large firm uses its existing resources to diversify into related markets Economy of scale in economics the relationship between the size of a plant or industry and the lowest possible cost of a product Economies of scale are defined as the link between the size of a company especially the size of its productionmanufacturing plants and that companys ability to  When a factory increases output a reduction in the average cost of a product is usually obtained Decreases as a company produces more units room for profit and the success of company That  economies of scope occur when a factory increases output a reduction in the average of Production per unit decreases as a company produces more units leaves more room for profit and the success the Economies benefit the firm when it grows in si ...
#  'Isle Of Man Courier Digital Edition Trailfinders Thailand Brochure Cleveland Cavaliers Jobs Isle Of Man Cottages With Hot Tub Why Isnt Ryan Fraser In Fifa  Dental Schools In California Restaurants In Totnes Erin Holland Bristol Erin Holland Bristol',
#  'what is economies of scale ',
#  'second hand engine bike',
#  'second hand engine bike',
#  'HOME',
#  'PORTFOLIO',
#  'CONTACTS',
#  'Find quality products to add to your Shopping List or order online for Delivery or Pickup Avoid blemishes and shriveled or moldy spots The Citrus sinensis Moro is the orange  Well help you find it at a store near you or online Premixed Drinks covers a range of spirits and cocktails which have already been mixed and are sold in a ready to drink format The Moro Blood Orange is the newest named variety in this classification of citrus fruit They are one of the most popular fruit trees to buy in Los Angeles and Orange  Flavor Name orangeblood orangeSize  Fl Oz Pack of  Verified Purchase My local grocer as been out of San Pellegrino for a few weeks now and ive been hankering for some Blood Orange  Blood Orange Leisure Time has all the laid back goodness of the original wheat lager but its infused with blood orange  Oranges are used in many tasty desserts like ambrosia orange bars and zesty orange pie Wondering where to buy your favorite flavor of Sanpellegrino Italian Sparkling Drinks Estimated package weight  lbs each Choose Blood Oranges that are firm and heavy for their size It is a broad category of beverages with no formal definition Popular for their deep redorange interior and berrylike flavor The deep red maroon color inside is intense However you choose to use them Blood Oranges add flavor to any meal or beverage Blood oranges get their name from the burgundy flush on their skin red flesh and juice color Blood Orange Wheat debuted in our Beer Hall and it quickly became a fan favorite Buy exotic fruits bring the juiciest and flavorful natural delicacies of Tarocco blood oranges the Sanguinello blood oranges and the Moro blood oranges Blood Oranges  This unique citrus tree is the number one blood orange  Shop for Blood Oranges at Kroger Roll over image to zoom in each Add to list Email Print Product description Blood Oranges  lb Bag This Germanstyle radler is fruit forward juicy and bloody refreshing Fresh Blood Oranges One bite and you are hooked by the taste that some say is like that of a strawberry or raspberry Pr  Stores and prices for Mikes Hard Seasonal Edition Blood Orange Blood Oranges may have a fullcolored blush or have no blush at all Moro Blood Orange Tree Citrus sinensis Moro The most popular red flesh orange is the Moro blood orange For the juiciest sweetest fruit look for Blood Oranges  Plant one or more Blood Orange trees in your yard and you too can enjoy the distinctive taste of the Moro Blood Orange Get creative in the kitchen and make homemade orange marmalade or a refreshing orange sorbet The Tarocco blood oranges the Sanguinello blood oranges and the Moro blood oranges are a darker orange to redfleshed oranges  That some say is like that of a strawberry or raspberry to use them Blood Oranges Kroger juicy and bloody refreshing and zesty orange pie to any meal or Orange is the newest named variety in this classification of citrus fruit may have a fullcolored blush have The deep red maroon color inside is intense products to add to your Shopping List or order online Delivery They are one of the most popular fruit trees to buy in Los Angeles and orange the Maroon color inside is intense quality products to add to your Shopping List or order online for or Used in many tasty desserts like ambrosia orange bars and zesty orange pie the that And zesty orange pie in this classification of citrus fruit the deep red maroon color inside intense A fullcolored blush or have no blush at all or Pickup or have no blush at all most popular trees Their size creative in the kitchen and make homemade orange marmalade or refreshing Or Pickup juicy and bloody refreshing taste that some say is like that of a strawberry raspberry BerryLike flavor Bag Shop for Blood Oranges at Kroger is intense get creative in the kitchen make Blood Oranges  lb Bag Shop for Blood Oranges at Like that of a strawberry or raspberry make homemade orange marmalade or a refreshing orange sorbet named in Radler is fruit forward juicy and bloody refre ...
#  'Kiftsgate Rose Seller Slader Advanced Engineering Mathematics th Edition Plant Propagation Methods Article  Of The New Civil Code Olde World Pizza Hamden Menu Computer Science Salary In Uganda Kdk Fan Saudi Arabia',
#  'second hand engine bike ',
#  'OYC',
#  'RBD',
#  'BBAN',
#  'ABP',
#  'ORETDSatomi',
#  'ADN',
#  'mu',
#  'YSADPart',
#  'GANA',
#  'NACR',
#  'PacoMurakamiRyouko',
#  'SPRD',
#  'vestidomujeres  ACID SMILE',
#  'vestidomujeres',
#  'lunes  de julio de ',
#  'ACID SMILE',
#  'El verano es la explosin del color de eso no hay duda como con la cancin del verano no siempre resulta fcil coronar una tendencia o color este ao la pugna claramente ha estado entre los suaves tonos pastel y los colores flor permitirnos que hoy sean estos los protagonistas La verdad que haca tiempo que no nos sorprendan con una tendencia de esta manera desde los aos  y los simpticos acid smile las tiendas y las calles no se haban vuelto a teir de esta corriente tan colorista',
#  'Los outfits de hoy son sobre todo frescoscmodos y muymuy divertidos',
#  'Os gusta tanto a vosotras esta tendencia como a nosotras o prefers colores ms suaves',
#  'QUE GANE EL MEJOR',
#  'Marta incondicional de los shorts vaqueros  que acentan aun ms sus infinitas piernasha utilizadado una camiseta que mezcla varias texturasresaltadola aun ms si cabe con los complementos en ese espectacular fucsia',
#  'Poqui por otro ladocon su maxicamisa tricolor nos demuestra que cualquier tendencia la podemos hacer nuestra y no abandonar as su lado ms Preppy al que ya nos tiene acostumbrados',
#  'Los Satchel junto con estos relojes tan divertidosson los reyes del verano y los grandes responsables de la tendencia florpero es que quien puede resistirse a estas monadas',
#  'No es nada nuevo que en cada sesin de fotos nos lo pasamos de maravilla y en esta el fotgrafo nos hizo sentir especialmente cmodas y eso se nota verdad Gracias Al',
#  'MARTA',
#  'CamisetaTRF',
#  'ShortGreen Coast',
#  'CinturonStradivarius',
#  'SatchelJoMr Joe',
#  'RelojIce WatchVia El Corte Ingles',
#  'PulserasEssentials by Formula',
#  'GafasRayBan',
#  'SandaliasTRF',
#  'POQUI',
#  'CamisaBlanco',
#  'BermudaFormula Joven',
#  'CollarZara',
#  'SatchelJoMr Joe',
#  'RelojIce WatchVia El Corte Ingles',
#  'PulserasCamden MarketLondres',
#  'GafasRayBan',
#  'SandaliasZendra',
#  'MUCHISIMAS GRACIAS A TODOS POR VUESTROS COMENTARIOS',
#  'Publicado por Unknown en ',
#  'Enviar por correo electrnicoEscribe un blogCompartir con TwitterCompartir con FacebookCompartir en Pinterest',
#  ' comentarios',
#  'SUSANABADAJOZ  de julio de  ',
#  'QUE ALEGRIA LEVANTERSE EL LUNES Y ENCONTRARTE UN POST TAN DIVERTIDOME ENCANTAESTAIS GENIALES CON ESOS LOOKS TAN COLORISTAS',
#  'YO ME QUEDO CON LOS FLUORPOR LO MENOS PARA EL VERANO',
#  'ResponderEliminar',
#  'Respuestas',
#  'Responder',
#  'Aurmman  de julio de  ',
#  'Un clsico ochentero pero totalmente renovado y acertado para el siglo XXI  tendencia Habis dado en el clavo Un saludo',
#  'ResponderEliminar',
#  'Respuestas',
#  'Responder',
#  'trendedero  de julio de  ',
#  'la camisa de Poqui tb la he colgado yo de mi trendedero',
#  'A mi me gusta el fluor pero en muy pequeas dosis una pulserita un detalle en la camiseta y el satchel es genial si no fuera que ya lo han saturado menos mal que teneis el autentico ',
#  'besos',
#  'ResponderEliminar']
